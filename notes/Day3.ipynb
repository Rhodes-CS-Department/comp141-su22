# %%
#Lab-01 Address.py Solution

#This program prompts the user for name and address and prints it out using proper formatting

#Get inputs from the user separately
first = input("First name: ")
last = input("Last name: ")
street = input("Street address: ")
city = input("City: ")
state = input("State: ")
zip = input("Zip code: ")

#Output name and address with proper formatting
print(last, ", ", first, sep='') #overwrite sep argument to remove spaces
print(street)
print(city, ", ", state, " ", zip, sep='')

# %% [markdown]
# __Quiz-like Questions__
#
# For the following 3 cells, without running the code, write down what the code will output. I highly recommend getting out a pencil and paper for this. When you are done, run each cell to see if you are correct. This process is called tracing code, and it's an important skill to develop.

# %%
#Quiz-like Question 1

age = 2
dogName = "May"
print(dogName, "the dog is", int(age * 7))

# %%
#Quiz-like Question 2

a = 3
b = 1 + a
c = a - 3
a = b
print(a)

# %%
#Quiz-like Question 3

print(5 % 3)

# %% [markdown]
# # Day 3 - Branching Statements and conditionals
#
# ## if-statement
# ![if-statement.png](attachment:if-statement.png)
#
# Python syntax:
# ```
# if condition:
# 	Statement
# 	Statement
# ```
# * First line known as the if clause
# * Includes the keyword `if` followed by condition
# * The condition can be __True__ or __False__
# * When the if statement executes, the condition is tested, and if it is true the block statements are executed. Otherwise, block statements are skipped

# %%
#Change the values of a and b below and re-run the code to see how the output changes
a = 5
b = 5

if a < b:
    print("a is less than b")

if a > b:
    print("a is greater than b")
    
if a <= b:
    print("a is less than or equal to b")

if a >= b:
    print("a is greater than or equal to b")

# %% [markdown]
# ## Boolean Expressions and Relational Operators
#
# __Boolean expression:__ expression tested by if statement to determine if it is true or false
# * Example: `a > b` (True if `a` is greater than `b`; False otherwise)
#
# __Relational operator:__ determines whether a specific relationship exists between two values
# * Example: greater than (>)
#
# Expression | Meaning
# ------------ | -------------
# x > y | Is x greater than y?
# x < y | Is x less than y?
# x >= y | Is x greater than or equal to y?
# x <= y | Is x less than or equal to y?
# x == y | Is x equal to y?
# x != y | Is x not equal to y?
#
# == operator determines whether the two operands are equal to one another - __Do not confuse with assignment operator (=)__
#
# __Any relational operator can be used in a decision block__
# * Example: if balance == 0:
# * Example: if payment != balance:

# %%
#Exam-if.py
#This program asks the user for their 3 exam scores and calculates their average
#If the user says they did the extra credit assignment, 5 points is added to their average

exam1 = int(input("What is your first exam score? "))
exam2 = int(input("What is your second exam score? "))
exam3 = int(input("What is your third exam score? "))

average = (exam1 + exam2 + exam3) / 3

choice = input("Did you do the extra credit assignment (yes or no): ")
if choice == 'yes':
    average = average + 5

print("Your exam average is", average)

# %% [markdown]
# ## The if-else Statement
# ![if-else-statement.png](attachment:if-else-statement.png) ![if-else-explanation.png](attachment:if-else-explanation.png)

# %%
#Exam-if-else.py
#This program asks the user for their 3 exam scores and calculates their average
#If the user says they did the extra credit assignment, 5 points is added to their average
#Else no points are added to their average

exam1 = int(input("What is your first exam score? "))
exam2 = int(input("What is your second exam score? "))
exam3 = int(input("What is your third exam score? "))

average = (exam1 + exam2 + exam3) / 3

choice = input("Did you do the extra credit assignment (yes or no): ")
if choice == 'yes':
    print("Your exam average is", average+5)
else:
    print("Your exam average is", average)

# %% [markdown]
# ## Comparing Strings
#
# * Strings can be compared using the == and != operators
# * String comparisons are __case sensitive__
# * Strings can be compared using >, <, >=, and <=
# <ul>
#     <li>Compared character by character based on the ASCII values for each character</li>
#     <li>If shorter word is substring of longer word, longer word is greater than shorter word</li>
# </ul>
#
# ![stringComparison.png](attachment:stringComparison.png)

# %%
#CompareStrings.py
#This program takes in two names and prints them out in alphbetical order

name1 = input("Enter name 1: ")
name2 = input("Enter name 2: ")

print("Here are the names, listed alphabetically: ")

if name1 < name2:
    print(name1)
    print(name2)
else:
    print(name2)
    print(name1)

# %% [markdown]
# ## Tracing Code
#
# Being able to trace through code, without running it, helps you learn how to read code well.
#
# Trace through the following code and predict the output of the code without running it. Once you have your solution, run the code and see if you're correct.

# %%
x = 1
y = 2
z = 3

if x < y:
    x = x + 1
    z = x - 1

if y < z:
    y = y - 1
if x < y:
    x = x + 1
else:
    z = z + x + 1

print(x, y, z)

# %% [markdown]
# ## Practice Problems
#
# __legal.py__
#
# Write a program that prompts a user for his or her age and prints out whether or not they are (legally) allowed to drink alcohol.

# %% [markdown]
# __area.py__
#
# Write a program that asks the user if they want to calculate the area of a square or a triangle. (The user will type in square or triangle.)
# * If they enter square, then ask the user for the length of a side and print the area.
# * If they enter triangle, then ask the user for the base and height and print the area.

# %% [markdown]
# ## When if-else is not enough
#
# ![messy-if-else.png](attachment:messy-if-else.png)

# %%
#This program gets a numeric test score from the user and displays the corresponding letter grade

#Constants for the grade thresholds
A_SCORE = 90
B_SCORE = 80
C_SCORE = 70
D_SCORE = 60

#Get the score from the user
score = int(input("Enter your test score: "))

#Determine the correct letter grade
if score >= A_SCORE:
    print('Your grade is an A.')
else:
    if score >= B_SCORE:
        print('Your grade is a B.')
    else:
        if score >= C_SCORE:
            print('Your grade is a C.')
        else:
            if score >= D_SCORE:
                print('Your grade is a D.')
            else:
                print('Your grade is an F.')

# %% [markdown]
# ## The if-elif-else statement
#
# __if-elif-else statement:__ special version of a decision structure
# * Makes logic of nested decision structures simpler to write
# * Can include multiple elif statements
# * Syntax:
# ```
#             if condition1:
# 				statements
# 			elif condition2:
# 				statements
# 			else:
# 				statements
# ```

# %%
#This program gets a numeric test score from the user and displays the corresponding letter grade
#This program is equivalent to the previous program, but is much more readable

#Constants for the grade thresholds
A_SCORE = 90
B_SCORE = 80
C_SCORE = 70
D_SCORE = 60

#Get the score from the user
score = int(input("Enter your test score: "))

#Determine the correct letter grade
if score >= C_SCORE and score < B_SCORE:
    print("C.")
elif score >= A_SCORE:
    print('Your grade is an A.')
elif score >= B_SCORE:
    print('Your grade is a B.')
elif score >= D_SCORE:
    print('Your grade is a D.')
else:
    print('Your grade is an F.')

# %% [markdown]
# ## Logical Operators
#
# __Logical operators:__ operators that can be used to create complex Boolean expressions
# * `and` operator and `or` operator: binary operators, connect two Boolean expressions into a compound Boolean expression
# * `not` operator: unary operator, reverses the truth of its Boolean operand
#
# __The `and` operator__: Both individual tests must be True to make the entire statement True.
#
# ```
# if ___________ and ______________:
#     #do something
#
# else:
#     #do something else
# ```
#
# Truth Table for `and` operator
#
# Expression | Value of Expression
# ------------ | -------------
# False and False | False
# False and True | False
# True and False | False
# True and True | True
#
# __The `or` operator__: Both individual tests must be False to make the entire statement False.
#
# ```
# if ___________ or ______________:
#     #do something
#
# else:
#     #do something else
# ```
#
# Truth Table for `or` operator
#
# Expression | Value of Expression
# ------------ | -------------
# False and False | False
# False and True | True
# True and False | True
# True and True | True
#
#
# __The `not` operator__: Takes a Boolean expression as operand and reverses its logical value
# * Sometimes it may be necessary to place parentheses around an expression to clarify to what you are applying the not operator
# ```
# if not (__________):
#     #do something
# ```
#
# Truth Table for `not` operator
#
# Expression | Value of Expression
# ------------ | -------------
# False | True
# True | False
#
# ## Checking Numeric Ranges with Logical Operators
#
# To determine whether a numeric value is within a specific range of values, use `and`
# * Example: `x >= 10 and x <= 20`
#
# To determine whether a numeric value is outside of a specific range of values, use `or`
# * Example: `x < 10 or x > 20`
#
#
# ## Short Circuit Evaluation
#
# __Short circuit evaluation:__ deciding the value of a compound Boolean expression after evaluating only one sub expression
# * Performed by the or and and operators
# * For or operator: If left operand is true, compound expression is true. Otherwise, evaluate right operand
# * For and operator: If left operand is false, compound expression is false. Otherwise, evaluate right operand

# %%
#Examples of Short Circuit Evaluation with and operator

x = int(input()) #Try with 6, 4, and 12
if x >= 5 and x <= 10:
    print("Here")

# %%
#Examples of Short Circuit Evaluation with or operator

x = int(input()) #Try with 10, 45, 66
if x <= 10 or x >= 65:
    print("here")

# %% [markdown]
# ## Nested Decision Structures
#
# Sometimes the way information is presented, it seems like a nested if/else statement is necessary.
#
# Take for example this flow chart for a loan qualification program.
#
# ![nested-decision.png](attachment:nested-decision.png)

# %%
#This program determines whether a bank customer qualifies for a loan.

#Constants for minimum salary and minimum years on the job
MIN_SALARY = 30000.0
MIN_YEARS = 2

#Get the customer's annual salary
salary = float(input("Enter your annual salary: "))

#Get the number of years on the current job
years_on_job = int(input("Enter the number of years employed: "))

#Determine whether the customer qualifies
if salary >= MIN_SALARY:
    if years_on_job >= MIN_YEARS:
        print("You qualify for the loan.")
    else:
        print("You must have been employed for at least", MIN_YEARS, "years to qualify.")
else:
    print("You must earn at least $", format(MIN_SALARY, '.2f'), " per year to qualify.", sep='')

# %% [markdown]
# In the program above, there are really only 2 outcomes (qualify or don't qualify). The code makes it seem as there are 3 different potential outcomes. The code is copied below for you. Modify it below to only use one if/else block.

# %%
#This program determines whether a bank customer qualifies for a loan.

#Constants for minimum salary and minimum years on the job
MIN_SALARY = 30000.0
MIN_YEARS = 2

#Get the customer's annual salary
salary = float(input("Enter your annual salary: "))

#Get the number of years on the current job
years_on_job = int(input("Enter the number of years employed: "))

#Determine whether the customer qualifies
if salary >= MIN_SALARY:
    if years_on_job >= MIN_YEARS:
        print("You qualify for the loan.")
    else:
        print("You must have been employed for at least", MIN_YEARS, "years to qualify.")
else:
    print("You must earn at least $", format(MIN_SALARY, '.2f'), " per year to qualify.", sep='')

# %% [markdown]
# ## Review Questions
#
# 1. Does an `if` statement always need to be followed by an `else` statement?
# 2. If you write an `if-else` statement, under what circumstances do the statements that appear after the `else` clause execute?
# 3. Assume the variables a = 2, b = 4, c = 6. What do the following statements evaluate to (True or False)?
# <ol>
#     <li> a == 4 or b > 2 - True</li>
#     <li> 6 <= c and a > 3 - False</li>
#     <li> 1 != b and c != 3 - True</li>
#     <li> a >= -1 or a <= b - True</li>
#     <li> not (a > 2) - True</li>
# </ol>
#
#
# ## Practice Problems
#
# __birthday.py__
# * Create a program that asks the user when their birthday is (month and day as integers).
# * Print a message to the user specifying whether their birthday has passed for the year,
# has yet to come for the year, or is today.

# %% [markdown]
# __hobby.py__
# * Write a program to help people choose an outdoor hobby.
# * Ask the user what kind of weather they prefer: hot, mild, or cold. The user should be able to answer either with a
# word, or just the first letter (h, m, or c).
# <ul>
#     <li> If they chose hot weather, ask the user if they like water. If they say yes, tell the user they should take up swimming. If they say no, tell them to take up beach volleyball.</li>
#     <li>If they chose mild weather, ask the user if they like to run. If they say yes, tell them to take up soccer. If they say no, recommend golf.</li>
#     <li> If they chose cold weather, ask the user if they are afraid of heights. If they say yes, tell them to take up ice skating. If they say no, tell them to take up downhill skiing.</li>
# </ul>
# * For each secondary yes/no question, the user should be able to type in the entire word or just the first letter (y/n).

# %% [markdown]
# Please do the following:
#
# 1. Zybooks Assignment 3 - due by 10am tomorrow
# 2. Keep working on Project 1 (project01) - due Thursday by 11:59pm
